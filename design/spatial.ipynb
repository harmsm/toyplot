# %%
import logging
import numpy
import toyplot
toyplot.log.setLevel(logging.DEBUG)

# %%
numpy.random.seed(1234)
x = numpy.linspace(-10, 10, 500)
y = numpy.sin(x)
coordinates = numpy.column_stack((x, y))

# %%
import toyplot.spatial
qtree = toyplot.spatial.QuadTree(bbox=(
    coordinates[:,0].min(),
    coordinates[:,0].max(),
    coordinates[:,1].min(),
    coordinates[:,1].max(),
    ))
for index, coordinate in enumerate(coordinates):
    qtree.insert(item=index, point=coordinate)
    
print qtree
# Out:
# <toyplot.spatial.QuadTree with 172 nodes, 500 items>

# %%
area = (-0.49, 0.49, -0.49, 0.49)
intersection = qtree.intersect(area)
print len(intersection)
# Out:
# DEBUG:toyplot:intersect 1
# DEBUG:toyplot:intersect 2
# DEBUG:toyplot:intersect 3
# DEBUG:toyplot:intersect 3
# DEBUG:toyplot:intersect 1
# DEBUG:toyplot:intersect 2
# DEBUG:toyplot:intersect 3
# DEBUG:toyplot:intersect 3
# DEBUG:toyplot:intersect 1
# DEBUG:toyplot:intersect 2
# DEBUG:toyplot:intersect 3
# DEBUG:toyplot:intersect 3
# DEBUG:toyplot:intersect 1
# DEBUG:toyplot:intersect 2
# DEBUG:toyplot:intersect 3
# DEBUG:toyplot:intersect 3
# 24

# %%
color = numpy.repeat("black", len(coordinates)).astype("S10")
color[list(intersection)] = "red"

canvas = toyplot.Canvas()
axes = canvas.axes(aspect=None)
axes.scatterplot(coordinates[:,0], coordinates[:,1], color=color)
axes.rects(area[0], area[1], area[2], area[3], style={"fill":"none", "stroke":"red"})
def walk(node):
    axes.rects(node.bbox.xmin, node.bbox.xmax, node.bbox.ymin, node.bbox.ymax, style={"fill":"none"})
    for child in node.nodes:
        walk(child)
walk(qtree.root)
# Out:
# <div align="center" class="toyplot" id="t36972f255505410bb3663c20dff7c378"><svg height="600px" id="tca79ad62e7604b4e91715c6174ff6110" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t382473c415044a4ba41995af8a4b363e"><clipPath id="t6882d1e2e4784756955aad8dde47c89d"><rect height="520.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t6882d1e2e4784756955aad8dde47c89d)" style="cursor:crosshair"><rect height="520.0" style="pointer-events:all;visibility:hidden" width="520.0" x="40.0" y="40.0"></rect><g class="toyplot-mark-Scatterplot" id="tb2eb7d795bd5444fa1c46e556620eacc" style=""><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="50.0" cy="163.9947222776575" r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="51.002004008016044" cy="172.50922793193948" r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="52.004008016032039" cy="181.22850980159808" r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="53.006012024048083" cy="190.13856293934947" r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="54.008016032064134" cy="199.22507598029401" r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="55.010020040080178" cy="208.47345412889234" r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="56.012024048096173" cy="217.86884260118663" r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="57.014028056112217" cy="227.39615048461854" r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="58.016032064128261" cy="237.04007497711473" r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="59.018036072144305" cy="246.78512596651314" r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="60.020040080160307" cy="256.61565091084589" r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="61.022044088176358" cy="266.51585997951963" r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="62.024048096192402" cy="276.46985141500568" r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="63.026052104208404" cy="286.46163707431106" r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(0%,0%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0"><circle cx="64.028056112224434" cy="296.47516810920251" r="2.0"></circle></g><g class="toyplot-Datum" style="fill:rg ...
